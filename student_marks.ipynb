# %%
import pandas as pd

data = {
    "Name": ["Ali", "Sara", "John"],
    "Marks": [85, 92, 78]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Name  Marks
# 0   Ali     85
# 1  Sara     92
# 2  John     78
